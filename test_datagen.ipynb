# %%
import pandas as pd
import cloudpickle

# This is the output of the data_gen script.
df = pd.read_csv(f'data/rsim.csv')

# Also load the forwarding tables
with open('data/rsim.ft', 'rb') as f:
    ft = cloudpickle.load(f)

# %%
# Dataframe of the packet data.
df
# Out:
#         timestamp     pkt_len  cur_hub  cur_port                         path  \
# 0        0.007254   11.565809       24         0                         24_0
# 1        0.016507   67.686781       10         1                    24_0-10_1
# 2        0.025760   44.873290        9         2                24_0-10_1-9_2
# 3        0.035012  108.017796        2         0            24_0-10_1-9_2-2_0
# 4        0.044265   42.433538        5         0        24_0-10_1-9_2-2_0-5_0
# ...           ...         ...      ...       ...                          ...
# 51309  999.831114  172.284057       11         1                    27_0-11_1
# 51310  999.855005  104.513099        9         2                27_0-11_1-9_2
# 51311  999.878897   19.355884        2         3            27_0-11_1-9_2-2_3
# 51312  999.902789  118.037129       17         1       27_0-11_1-9_2-2_3-17_1
# 51313  999.926681   15.072558       19         2  27_0-11_1-9_2-2_3-17_1-19_2
#
#        priority  flow_id scheduler       etime
# 0             0        2      FIFO    0.016507
# 1             0        2      FIFO    0.025760
# 2             0        2      FIFO    0.035012
# 3             0        2      FIFO    0.044265
# 4             0        2      FIFO    0.053518
# ...         ...      ...       ...         ...
# 51309         0        4      FIFO  999.855005
# 51310         0        4      FIFO  999.878897
# 51311         0        4      FIFO  999.902789
# 51312         0        4      FIFO  999.926681
# 51313         0        4      FIFO  999.950573
#
# [51314 rows x 9 columns]

# %%
# Forwarding table
# Keys are devices, values are the forwarding table dictionary (flow_id -> port_number)
ft
# Out:
# {0: {3: 0},
#  1: {},
#  2: {2: 0, 4: 3},
#  3: {0: 2},
#  4: {3: 0},
#  5: {2: 0},
#  6: {2: 3, 3: 2},
#  7: {},
#  8: {},
#  9: {0: 3, 2: 2, 4: 2},
#  10: {0: 1, 2: 1},
#  11: {1: 3, 4: 1},
#  12: {3: 2},
#  13: {0: 1},
#  14: {3: 0},
#  15: {0: 3},
#  16: {},
#  17: {4: 1},
#  18: {},
#  19: {4: 2},
#  20: {},
#  21: {},
#  22: {},
#  23: {},
#  24: {0: 0, 2: 0},
#  25: {},
#  26: {1: 0},
#  27: {4: 0},
#  28: {3: 0},
#  29: {},
#  30: {},
#  31: {},
#  32: {},
#  33: {},
#  34: {},
#  35: {}}
